# %%
# Import libraries
import json 
import pandas as pd

# %%
SI_Course_Map = {
    "CHEM 1103": {"New_Code": "CHEM 14103", "Title": "University Chemistry I"},
    "CHEM 1123": {"New_Code": "CHEM 14203", "Title": "University Chemistry II"},
    "CHEM 1123H": {"New_Code": "CHEM 142H3", "Title": "Honors Chemistry II"},
    "CHEM 1073": {"New_Code": "CHEM 12103", "Title": "Fundamentals of Chemistry"},
    "CHEM 1073 Online": {"New_Code": "CHEM 12103 Online", "Title": "Fundamentals of Chemistry Online"},
    "CHEM 3603": {"New_Code": "CHEM 36053", "Title": "Organic Chemistry I"},
    "BIOL 1543": {"New_Code": "BIOL 10103", "Title": "Principles of Biology"},
    "CHEM 2613": {"New_Code": "CHEM 26103", "Title": "Organic Physiological Chemistry"},
    "CHEM 3613": {"New_Code": "CHEM 36203", "Title": "Organic Chemistry II"},
    "NURS 3314": {"New_Code": "NURS 33174", "Title": "Pathophysiology"},
    "UNIV 1001": {"New_Code": "UNIV 10051", "Title": "University Perspectives"},
    "ACCT 2013": {"New_Code": "ACCT 20103", "Title": "Accounting Principles"},
    "ACCT 2013 Online": {"New_Code": "ACCT 20103 Online", "Title": "Accounting Principles Online"},
    "ACCT 2023": {"New_Code": "ACCT 20203", "Title": "Accounting Principles II"},
    "ACCT 2023 Online": {"New_Code": "ACCT 20203 Online", "Title": "Accounting Principles II Online"},
    "ECON 2013": {"New_Code": "ECON 21003", "Title": "Principles of Macroeconomics"},
    "ECON 2013 Online": {"New_Code": "ECON 21003 Online", "Title": "Principles of Macroeconomics Online"},
    "ECON 2013H": {"New_Code": "ECON 2100H3", "Title": "Honors Principles of Macroeconomics"},
    "ECON 2023": {"New_Code": "ECON 22003", "Title": "Principles of Microeconomics"},
    "ECON 2023 Online": {"New_Code": "ECON 22003 Online", "Title": "Principles of Microeconomics Online"},
    "ECON 2023H": {"New_Code": "ECON 220H3", "Title": "Honors Principles of Microeconomics"},
    "ECON 2143": {"New_Code": "ECON 21403", "Title": "Basic Economics: Theory and Practice"},
    "ECON 2143 Online": {"New_Code": "ECON 21403 Online", "Title": "Basic Economics: Theory and Practice Online"},
    "ECON 2143H": {"New_Code": "ECON 214H3", "Title": "Honors Basic Economics: Theory and Practice"},
    "EXSC 3353": {"New_Code": "EXSC 33503", "Title": "Mechanics of Human Movement"},
    "CHEG 2113": {"New_Code": "CHEG 21103", "Title": "Introduction to Chemical Engineering I"},
    "CHEG 2133": {"New_Code": "CHEG 21303", "Title": "Fluid Mechanics"},
    "MATH 2043": {"New_Code": "MATH 22003", "Title": "Survey of Calculus"},
    "WCOB 1033": {"New_Code": None, "Title": "Data Analysis"},
}

# %%
SI_Course_Map_df = pd.DataFrame([
    {"Old_Code": old, "New_Code": data["New_Code"], "Title": data["Title"]}
    for old, data in SI_Course_Map.items()
])

# %%
SI_Course_Map_df
# Out:
#             Old_Code           New_Code  \
# 0          CHEM 1103         CHEM 14103
# 1          CHEM 1123         CHEM 14203
# 2         CHEM 1123H         CHEM 142H3
# 3          CHEM 1073         CHEM 12103
# 4   CHEM 1073 Online  CHEM 12103 Online
# 5          CHEM 3603         CHEM 36053
# 6          BIOL 1543         BIOL 10103
# 7          CHEM 2613         CHEM 26103
# 8          CHEM 3613         CHEM 36203
# 9          NURS 3314         NURS 33174
# 10         UNIV 1001         UNIV 10051
# 11         ACCT 2013         ACCT 20103
# 12  ACCT 2013 Online  ACCT 20103 Online
# 13         ACCT 2023         ACCT 20203
# 14  ACCT 2023 Online  ACCT 20203 Online
# 15         ECON 2013         ECON 21003
# 16  ECON 2013 Online  ECON 21003 Online
# 17        ECON 2013H        ECON 2100H3
# 18         ECON 2023         ECON 22003
# 19  ECON 2023 Online  ECON 22003 Online
# 20        ECON 2023H         ECON 220H3
# 21         ECON 2143         ECON 21403
# ...

# %%
# Save as JSON
with open("SI_Course_Map.json", "w") as f:
    json.dump(SI_Course_Map, f, indent=4)

# %%
# Save as Python Dictionary
with open("SI_Course_Map.py", "w") as f:
    f.write("course_map = ")
    json.dump(SI_Course_Map, f, indent=4)

# %%
# Save as CSV
SI_Course_Map_df.to_csv("SI_Course_Map.csv", index=False)

# %%
# Save as Excel
SI_Course_Map_df.to_excel("SI_Course_Map.xlsx", index=False)
